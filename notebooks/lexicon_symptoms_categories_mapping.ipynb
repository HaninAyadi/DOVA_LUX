# %%
import pandas as pd 
import json
import re

# %% [markdown]
# ### Level 1: From synonyms to a single symptom

# %%
#### Reading long covid symptoms lexicon dataframe
lexicon = pd.read_csv('post_covid19_symptom_lexicon.csv')
lexicon.head()
# Out:
#       symptom                         consolidated_UMLS_concepts  \
# 0        pain  C0030193:Pain|C0150055:Chronic Pain|C0151825:B...
# 1     anxiety  C0003467:Anxiety|C0003469:Anxiety Disorder|C00...
# 2  depression  C0001539:Adjustment Disorder With Depressed Mo...
# 3     fatigue  C0015672:Fatigue|C0015674:Chronic Fatigue Synd...
# 4  joint pain  C0003862:Joint Pain|C0007859:Neck Pain|C001955...
#
#                                             synonyms  percentage  ranking
# 0  A26-A29 TYPES OF PAIN|abdominal cramps|abdomin...       0.431        1
# 1  ["Nerves"] or [nervousness] or [nervous tensio...       0.258        2
# 2   Reactive depression NOS|9-52 DEPRESSIVE DISOR...       0.240        3
# 3  (non-specific) malaise and fatigue|Akureyri|Ak...       0.234        4
# 4  (Cervicalgia) or (neck pain NOS)|Ache in joint...       0.210        5

# %%
#### building list of the basic symptoms
basic_symptom_list = lexicon.symptom.to_list()
basic_symptom_list_indices = lexicon.index.to_list()
basic_symptom_list = [symptom.strip() for symptom in basic_symptom_list]

#### fixing the name of a particular symptom : from 'postcoital\xa0bleeding' to 'postcoital bleeding'
basic_symptom_list[315] = 'postcoital bleeding'

# %%
consolidated_UMLS_concepts_list = [re.sub(r'C[0-9]*:', '', concept) for concept in lexicon.consolidated_UMLS_concepts.to_list()]
consolidated_UMLS_concepts_list = [s.split('|') for s in consolidated_UMLS_concepts_list]
lexicon['consolidated_UMLS_concepts_list'] = consolidated_UMLS_concepts_list
uml_concepts_exploded_df = lexicon.explode('consolidated_UMLS_concepts_list')
consolidated_UMLS_concepts_list_lower = [concept.lower() for concept in uml_concepts_exploded_df.consolidated_UMLS_concepts_list.to_list()]
consolidated_UMLS_concepts_list_indices = uml_concepts_exploded_df.index.to_list()

# %%
synonym_symptoms_list_flat = lexicon.synonyms
for punc in ['|']:
    synonym_symptoms_list = [s.split(punc) for s in synonym_symptoms_list_flat]
    synonym_symptoms_list_flat = [word.lower().strip() for symptom_list in synonym_symptoms_list for word in symptom_list]

lexicon['synonym_symptoms_list'] = synonym_symptoms_list
synonym_symptoms_list_exploded_df = lexicon.explode('synonym_symptoms_list')
synonym_symptoms_list_lower = [synonym.lower() for synonym in synonym_symptoms_list_exploded_df.synonym_symptoms_list.to_list()]
synonym_symptoms_list_indices = synonym_symptoms_list_exploded_df.index.to_list()

# %%
#### creating final symptoms synonyms lists
lexicon_symptoms_list = basic_symptom_list + consolidated_UMLS_concepts_list_lower + synonym_symptoms_list_lower
lexicon_symptoms_list_indices = basic_symptom_list_indices + consolidated_UMLS_concepts_list_indices + synonym_symptoms_list_indices

# %%
#### creating symptoms dictionary 
#### each symptom synonym is associated with the appropriate indices of the original symptom

lexicon_symptoms_dict = {}
for i, j in zip(lexicon_symptoms_list, lexicon_symptoms_list_indices):
    if i not in lexicon_symptoms_dict.keys():
        lexicon_symptoms_dict[i] = [j]
    else:
        #### for the symptom synonyms that are associated with multiple symptoms
        values_list = []
        if type(lexicon_symptoms_dict[i]) == list:
            values_list.extend(lexicon_symptoms_dict[i])
            values_list.append(j)
            lexicon_symptoms_dict[i] = values_list
        else:
            values_list.append(lexicon_symptoms_dict[i])
            values_list.append(j)
            lexicon_symptoms_dict[i] = values_list
            
lexicon_symptoms_dict = {k: list(set(v)) for (k, v) in lexicon_symptoms_dict.items()}
lexicon_symptoms_dict
# Out:
# {'pain': [0],
#  'anxiety': [1],
#  'depression': [2],
#  'fatigue': [3],
#  'joint pain': [4],
#  'shortness of breath': [5],
#  'headaches': [6],
#  'nausea and/or vomiting': [7],
#  'myalgia': [8],
#  'gastroesophageal reflux': [9],
#  'cough': [10],
#  'back pain': [11],
#  'stress': [12],
#  'fever': [13],
#  'swelling': [35, 14],
#  'bleeding': [15],
#  'weight loss': [16],
#  'abdominal pain': [17],
#  'dizziness or vertigo': [18],
#  'chest pain': [19],
#  'weakness': [20],
#  'constipation': [21],
#  'skin lesion': [22],
#  'wheezing': [23],
#  'rash': [24],
#  'insomnia': [25],
#  'pain in extremities': [26],
#  'paresthesia': [27],
#  'peripheral edema': [28],
#  'palpitations': [29],
#  'diarrhea': [30],
#  'itching': [31],
#  'erythema': [32],
#  'lower urinary tract symptoms': [33],
#  'lymphadenopathy': [34],
#  'edema': [35],
#  'weight gain': [36],
#  'sinonasal congestion': [37],
#  'pain in throat': [38],
#  'abnormal gait': [39],
#  'respiratory depression': [40],
#  'visual changes': [41],
#  'chills': [42],
#  'urinary incontinence': [43],
#  'sleep apnea': [44],
#  'confusion': [45],
#  'hearing loss': [46],
#  'problem with smell or taste': [47],
#  'dysphagia': [48],
#  'loss of appetite': [49],
#  'abnormal breathing': [50, 5],
#  'burning sensation': [51],
#  'syncope': [52],
#  'hematuria': [53],
#  'bruising': [54],
#  'pelvic pain': [55],
#  'anaphylaxis': [56],
#  'sleep disorder': [57],
#  'mental status change': [58],
#  'somnolence': [59],
#  'hives': [60],
#  'memory impairment': [61],
#  'tremor': [62],
#  'sweating': [63],
#  'gastrointestinal hemorrhage': [64],
#  'seizure': [65],
#  'irritable': [66],
#  'chest tightness': [67],
#  'cramping': [98, 68],
#  'snoring': [69],
#  'abdominal bloating': [70],
#  'agitation': [71],
#  'dermatitis': [72],
#  'murmur': [73],
#  'impaired cognition': [74],
#  'hair loss': [75],
#  'flushing': [76],
#  'paralysis and hemiplegia': [77],
#  'stiffness': [78],
#  'facial pain': [79],
#  'suffering': [80],
#  'ulcer': [81, 22],
#  'mood swings': [82],
#  'suicidal': [83],
#  'aggression': [84],
#  'bronchospasm': [85],
#  'panic': [86],
#  'musculoskeletal pain': [87],
#  'spasm': [88, 98],
#  'sexual dysfunction': [89],
#  'respiratory syndrome': [90],
#  'nocturia': [91],
#  'urinary retention': [92],
#  'vaginal bleeding': [93],
#  'blurred vision': [94],
#  'muscle stiffness': [95],
#  'crying associated with mood': [96],
#  'tenderness': [8, 97],
#  'muscle cramps': [88, 98],
#  'blood in stools': [99],
#  'pale': [100],
#  'weight change': [101],
#  'difficulty speaking': [102],
#  'chest discomfort': [103],
#  'warm skin': [104],
#  'ear pain': [105],
#  'hyperactivity': [106],
#  'loss of consciousness': [58, 107],
#  'passing gas': [108],
#  'fluid retention': [109],
#  'hungry': [110],
#  'tinnitus': [111],
#  'bradycardia': [112],
#  'menorrhagia': [113],
#  'dyspepsia': [114],
#  'sneezing': [115],
#  'muscle weakness': [116],
#  'hot flushes': [117],
#  'self-harm': [118],
#  'hoarseness': [119],
#  'night sweats': [120],
#  'walking disability': [121],
#  'grieving': [122],
#  'nosebleed': [123],
#  'poor concentration': [124],
#  'anger': [125],
#  'photosensitivity': [126],
#  'menstrual spotting': [93, 127],
#  'restlessness': [128, 158, 71],
#  'blindness': [129],
#  'vaginal discharge symptom': [130],
#  'hemoptysis': [131],
#  'hallucinations': [132],
#  'breast lump': [133],
#  'joint stiffness': [134],
#  'gi upset': [135],
#  'gastrointestinal symptom': [136],
#  'restless legs': [137],
#  'irregular periods': [138],
#  'abnormal uterine bleeding': [139],
#  'breast tenderness': [140],
#  'clouded consciousness': [141],
#  'ecchymosis': [142],
#  'dysmenorrhea': [143],
#  'limitation of joint movement': [144],
#  'psychosis': [145],
#  'homicidal thoughts': [146],
#  'skin irritation': [147],
#  'increased appetite': [148],
#  'incontinence of feces': [149],
#  'myotonia': [150],
#  'ocular edema': [151],
#  'flat affect': [152],
#  'impulsive character': [153],
#  'inadequate oral intake': [154],
#  'joint swelling': [155],
#  'tendency to bleed': [156],
#  'short menstrual periods': [157],
#  'psychomotor agitation': [158, 71],
#  'abnormal behavior': [159],
#  'angioedema': [160],
#  'rhinitis': [161],
#  'disorientation': [162, 45],
#  'near syncope': [163],
#  'perseveration': [164],
#  'hypesthesia': [165],
#  'slurred speech': [166],
#  'thirsty': [167],
#  'easy bruising': [168],
#  'burping': [169],
#  'polyuria': [170],
#  'cold sores': [171],
#  'paranoia': [172],
#  'impaired skin integrity': [173],
#  'temperature intolerance': [174],
#  'dry skin': [175],
#  'sputum color change': [176],
#  'dysphoria': [177],
#  'muscle twitching': [178],
#  'reduced mobility': [179],
#  'dyspareunia': [180],
#  'feces color: tarry': [181],
#  'feeling unhappy': [182],
#  'urinary changes': [183],
#  'photopsia': [184],
#  'skin necrosis': [185],
#  'feeling lonely': [186],
#  'behavior showing increased motor activity': [187],
#  'skin hypertrophy': [188],
#  'jaundice': [189],
#  'delusions': [190],
#  'fidgeting': [191],
#  'skin discoloration': [192],
#  'altered bowel function': [193],
#  'gagging': [194],
#  'lump in throat': [195],
#  'itchy throat': [196],
#  'motor dysfunction': [197],
#  'facial edema': [198],
#  'physical deconditioning': [199],
#  'stridor': [200],
#  'loss of motivation': [201],
#  'anhedonia': [202],
#  'ulcer of mouth': [203],
#  'claustrophobia': [204],
#  'feeling bad': [3, 205],
#  'compulsion expressed as ritual': [206],
#  'manic mood': [207],
#  'disturbance in speech': [208],
#  'amenorrhea': [209],
#  'muscle strain': [8, 210],
#  'neurological symptom': [211],
#  'thin skin': [212],
#  'unable to move': [213],
#  'aura': [214],
#  'erythematous mucosa': [215],
#  'libido disorder': [216],
#  'unable to speak': [217],
#  'intolerance to food': [218],
#  'itchy eyes': [219],
#  'multiple symptoms': [220],
#  'dysthymia': [221],
#  'eye hemorrhage': [222],
#  'nasal obstruction': [223],
#  'lip swelling': [224],
#  'nasal polyp': [225],
#  'hirsutism': [226],
#  'loss of interest': [227],
#  'visual hallucinations': [228],
#  'subluxation of joint': [229],
#  'early satiety': [230],
#  'grinding teeth': [231],
#  'habit tic': [232],
#  'racing thoughts': [233],
#  'abusive behavior': [234],
#  'esophageal spasm': [235],
#  'preoccupied': [236],
#  'frailty': [237],
#  'hypotrichosis': [238],
#  'soft stool': [239],
#  'watery eye': [240],
#  'grimaces': [241],
#  'red eye': [242],
#  'twitching': [178, 243],
#  'change in voice': [244],
#  'facial hemiatrophy': [245],
#  'arrhythmia': [246],
#  'tongue swelling': [247],
#  'unable to stand': [248],
#  'lymphedema': [249, 28],
#  'menstrual problem': [250],
#  'impaired insight': [251],
#  'pink skin': [252],
#  'activity intolerance': [253],
#  'psychiatric symptom': [254],
#  'atrophy of vagina': [255],
#  'hypertrophy of nail': [256],
#  'gynecomastia': [257],
#  'bradykinesia': [258],
#  'flashbacks': [259],
#  'spasticity': [260],
#  'muscle fatigue': [261],
#  'impaired exercise tolerance': [262],
#  'difficulty balancing': [263],
#  'enlarged breast': [264],
#  'coordination problem': [265],
#  'oral lesion': [266],
#  'galactorrhea': [267],
#  'influenza-like illness': [268],
#  'polysubstance abuse': [269],
#  'myoclonus': [270],
#  'flank pain': [11, 271],
#  'foot tapping': [272],
#  'neuralgia': [273],
#  'ear blocked': [274],
#  'phonophobia': [275],
#  'thick skin': [276],
#  'hard stool': [277],
#  'feels cold': [278],
#  'palpable mass': [279],
#  'throat swelling': [280, 350],
#  'hiccups': [281],
#  'stuttering': [282],
#  'chloasma': [283],
#  'increased energy': [284],
#  'vocal fatigue': [285],
#  'mania nos': [342, 286],
#  'menopausal symptom': [287],
#  'dry mouth': [288],
#  'discomfort': [289],
#  'clonus': [290],
#  'imbalance': [291],
#  'hemiplegia': [292],
#  'throat tightness': [293],
#  'facial numbness': [294],
#  'ataxia': [295],
#  'dystonia': [296],
#  'choking sensation': [297],
#  'dyskinesia': [298],
#  'purpura': [299],
#  'thrombophlebitis': [300],
#  'oliguria': [33, 301],
#  'nasal symptoms': [302],
#  'involuntary movement': [303],
#  'hypomania': [304],
#  'akathisia': [305],
#  'tardive dyskinesia': [306],
#  'laryngeal edema': [307],
#  'violent': [308],
#  'tunnel vision': [309],
#  'dissociation': [310],
#  'cyanosis': [311],
#  'muscle spasms': [312, 106, 88],
#  'trismus': [313],
#  'throat symptom': [314],
#  'postcoital bleeding': [315],
#  'dysesthesia': [51, 316],
#  'eye swelling': [317, 151],
#  'hyperemesis': [318],
#  'optic papillitis': [319],
#  'cold extremities': [320],
#  'eye inflammation': [321],
#  'personality change': [322],
#  'cold sweat': [323],
#  'hypothermia': [324],
#  'neck spasms': [325],
#  'coma': [326],
#  'catatonia': [327],
#  'sore tongue': [328],
#  'choking': [329],
#  'jaw pain': [330, 79],
#  'combativeness': [331],
#  'keratoconjunctivitis sicca': [332],
#  'neuropathic pain': [0, 273, 333],
#  'rash with mucosal lesions': [334],
#  'oral tingling': [335],
#  'mucositis': [336],
#  'priapism': [337],
#  'morbilliform rash': [338],
#  'canker sores': [339],
#  'feeling intoxicated': [340],
#  'gum hyperplasia': [341],
#  'mania': [342, 207],
#  'disinhibition': [343],
#  'changes in skin texture': [344],
#  'hyperthermia': [345, 13],
#  'tongue burning': [346],
#  'black hairy tongue': [347],
#  'excessive somnolence': [348],
#  'drooling': [349],
#  'oropharyngeal swelling': [350],
#  'cns symptom': [351],
#  'facial swelling': [352, 198, 14],
#  'tetany': [353],
#  'dry eyes': [354, 332],
#  'chronic pain': [0],
#  'bone pain': [0],
#  'acute pain': [0],
#  'painful mouth': [0],
#  'pain crisis': [0],
#  'pain in buttock': [0],
#  'precordial pain': [0],
#  'superficial pain': [0],
#  'deep pain': [0],
#  'burning pain': [0],
#  'aching pain': [0],
#  'pain and tenderness': [0],
#  'somatic pain': [0],
#  'referred pain': [0],
#  'inflammatory pain': [0],
#  'mechanical pain': [0],
#  'rest pain': [0],
#  'radiating pain': [0],
#  'night pain': [0],
#  'smarting pain': [0],
#  'pain of skin': [0],
#  'suprapubic pain': [0],
#  'wound pain': [0],
#  'mild pain': [0],
#  'moderate pain': [0],
#  'severe pain': [0],
#  'excruciating pain': [0],
#  'exquisite pain': [0],
#  'dull pain': [0, 19],
#  'stabbing pain': [0],
#  'shooting pain': [0],
#  'radicular pain': [0],
#  'throbbing pain': [0],
#  'generalized aches and pains': [0],
#  'sharp pain': [0],
#  'total body pain syndrome': [0],
#  'complex regional pain syndrome': [0],
#  'cramping pain': [0],
#  'heavy pain': [0],
#  'other chronic pain': [0],
#  'localized pain': [0],
#  'diffuse pain': [0],
#  'pain in axilla': [0],
#  'uncontrolled pain': [0],
#  'painful scar': [0],
#  'intermittent pain': [0],
#  'chronic pain syndrome': [0],
#  'central pain syndrome': [0],
#  'constant pain': [0],
#  'squeezing pain': [0],
#  'spontaneous pain': [0],
#  'inadequate pain control': [0],
#  'very mild pain': [0],
#  'colicky pain': [0],
#  'tingling pain': [0],
#  'anxiety disorder': [1],
#  'nervousness': [1],
#  'adjustment disorder with anxious mood': [1],
#  'anticipatory anxiety': [1],
#  'mild anxiety': [1],
#  'moderate anxiety': [1],
#  'alcohol-induced anxiety disorder': [1],
#  'organic anxiety disorder': [1],
#  'generalized anxiety disorder': [1],
#  'anxiety hyperventilation': [1],
#  'other mixed anxiety disorders': [1],
#  'anxiety and fear': [1],
#  'anxiety about body function or health': [1],
#  'anxiety about dying': [1],
#  'death anxiety': [1],
#  'feeling jittery': [1],
#  'anxiety about treatment': [1],
#  'chronic anxiety': [1],
#  'anxiety attack': [1],
#  'anxiety state': [1],
#  'feeling nervous': [1],
#  'anxiety neurosis': [1],
#  'anxious mood': [1],
#  'anxiety due to dementia': [1],
#  'adjustment disorder with depressed mood': [2],
#  'bipolar affective disorder, current episode depression': [2],
#  'reactive depression (situational)': [2],
#  'depressive disorder': [2],
#  'major depression, single episode': [2],
#  'symptoms of depression': [2],
#  'mild major depression, single episode': [2],
#  'moderate major depression, single episode': [2],
#  'recurrent major depressive episodes': [2],
#  'mild recurrent major depression': [2],
#  'moderate recurrent major depression': [2],
#  'adjustment disorder with mixed anxiety and depressed mood': [2],
#  'postpartum depression': [2],
#  'recurrent depression': [2],
#  'agitated depression': [2],
#  'recurrent major depression in partial remission': [2],
#  'depressed bipolar i disorder': [2],
#  'mild major depression': [2],
#  'moderate major depression': [2],
#  'severe major depression with psychotic features': [2],
#  'severe major depression with psychotic features, mood-congruent': [2],
#  'major depression in remission': [2],
#  'major depression in partial remission': [2],
#  'schizoaffective disorder, depressive type': [2],
#  'neurotic depression': [2, 221],
#  'bipolar affective disorder, currently depressed, mild': [2],
#  'bipolar affective disorder, currently depressed, moderate': [2],
#  'recurrent major depressive episodes, moderate': [2],
#  'mixed anxiety and depressive disorder': [2],
#  'depressed mood': [2],
#  'depressive episode': [2],
#  'mood disorder with depressive features due to general medical condition': [2],
#  'bipolar i disorder, most recent episode depressed with postpartum onset': [2],
#  'menopausal depression': [2],
#  'chronic recurrent major depressive disorder': [2],
#  'chronic depression': [2],
#  'mild depression': [2],
#  'moderate depression': [2],
#  'severe depression': [2],
#  'emotional upset': [2],
#  'depressive psychoses': [2],
#  'major depressive disorder': [2],
#  'emotional crisis': [2],
#  'acute depression': [2],
#  'depressed - symptom': [2],
#  'severe recurrent major depression': [2],
#  'severe major depression': [2],
#  'recurrent major depressive episodes, mild': [2],
#  'chronic depressive personality disorder': [2],
#  'moderately severe major depression': [2],
#  'minimal depression': [2],
#  'major depression with psychotic features': [2],
#  'chronic fatigue syndrome': [3],
#  'lethargy': [3],
#  'malaise and fatigue': [3],
#  'malaise': [3],
#  'exhaustion': [3],
#  'tires quickly': [3],
#  'tired all the time': [3],
#  'tired': [3],
#  'postexertional fatigue': [3],
#  'fatigue due to treatment': [3],
#  'occasionally tired': [3],
#  'neck pain': [4],
#  'hip pain': [4],
#  'shoulder pain': [4],
#  'greater trochanteric pain syndrome': [4],
#  'multiple joint pain': [4],
#  'girdle pain': [4],
#  'knee pain': [4],
#  'ankle pain': [4],
#  'pain of left shoulder joint': [4],
#  'pain of right shoulder joint': [4],
#  'anterior knee pain': [4],
#  'lumbar facet joint pain': [4],
#  'clavicle pain': [4],
#  'chronic neck pain': [4],
#  'pain radiating to neck': [4],
#  'pain of left temporomandibular joint': [4],
#  'pain of left ankle joint': [4],
#  'pain of left hip joint': [4],
#  'pain in left knee': [4],
#  'bilateral shoulder joint pain': [4],
#  'pain in right hip joint': [4],
#  'pain in right knee': [4],
#  'bilateral knee pain': [4],
#  'joint pain in ankle and foot': [4],
#  'pain of joint of left lower leg': [4],
#  'pain of joint of bilateral lower legs': [4],
#  'bilateral temporomandibular joint pain': [4],
#  'chronic sacroiliac joint pain': [4],
#  'dyspnea': [5],
#  'dyspnea on exertion': [5],
#  'nocturnal dyspnea': [5],
#  'unable to breathe': [5],
#  'increasing breathlessness': [5],
#  'dyspnea at rest': [5],
#  'paroxysmal nocturnal dyspnea': [5],
#  'winded': [5],
#  'chronic dyspnea': [5],
#  'cervico-occipital neuralgia': [6],
#  'cluster headache': [6],
#  'headache': [6],
#  'ocular headache': [6],
#  'posttraumatic headache': [6],
#  'psychogenic headache': [6],
#  'sinus headache': [6],
#  'migraine variants': [6],
#  'vascular headache': [6],
#  'migraine': [6],
#  'migraine with aura': [6],
#  'occipital headache': [6],
#  'frontal headache': [6],
#  'menstrual migraine': [6],
#  'headache following lumbar puncture': [6],
#  'abdominal migraine': [6],
#  'basilar migraine': [6],
#  'hemiplegic migraine': [6],
#  'migraine without aura': [6],
#  'ophthalmic migraine': [6],
#  'complicated migraine': [6],
#  'migraine aura without headache': [6],
#  'muscular headache': [6],
#  'episodic tension-type headache': [6],
#  'chronic tension-type headache': [6],
#  'episodic cluster headache': [6],
#  'chronic post-traumatic headache': [6],
#  'headache associated with sexual activity': [6],
#  'throbbing headache': [6],
#  'aching headache': [6],
#  'temporal headache': [6],
#  'bilateral headache': [6],
#  'thalamic pain': [6],
#  'c/o - a headache': [6],
#  'cervicogenic headache': [6],
#  'generalized headache': [6],
#  'other forms of migraine nos': [6],
#  'drug withdrawal headache': [6],
#  'primary thunderclap headache': [6],
#  'benign exertional headache': [6],
#  'analgesic overuse headache': [6],
#  'viral headache': [6],
#  'morning headache': [6],
#  'acute headache': [6],
#  'migraine variant with headache': [6],
#  'cough headache syndrome': [6],
#  'idiopathic stabbing headache': [6],
#  'chronic daily headache': [6],
#  'unilateral headache': [6],
#  'frequent headache': [6],
#  'intermittent headache': [6],
#  'migraine with typical aura': [6],
#  'refractory migraine with aura': [6],
#  'refractory migraine': [6],
#  'transformed migraine': [6],
#  'chronic headache disorder': [6],
#  'medication overuse headache': [6],
#  'new daily persistent headache': [6],
#  'intractable episodic cluster headache': [6],
#  'intractable episodic tension-type headache': [6],
#  'daily headache': [6],
#  'postural headache': [6],
#  'nausea': [7],
#  'nausea and vomiting': [7],
#  'vomiting': [7],
#  'nausea, vomiting and diarrhea': [7],
#  'cyclical vomiting syndrome': [7],
#  'persistent vomiting': [7],
#  'projectile vomiting': [7],
#  'chronic vomiting': [7],
#  'bilious vomiting': [7],
#  'self-induced vomiting': [7],
#  'retching': [7],
#  'morning nausea': [7],
#  'intermittent vomiting': [7],
#  'nausea present': [7],
#  'diarrhea and vomiting, symptom': [7],
#  'increased nausea and vomiting': [7],
#  'vomiting food': [7],
#  'vomit contains blood': [7],
#  'coffee ground vomiting': [7],
#  'post-tussive vomiting': [7],
#  'morning vomiting': [7],
#  'intractable nausea and vomiting': [7],
#  'fibromyalgia': [8],
#  'myalgia and myositis unspecified': [8],
#  'sprains and strains of joints and adjacent muscles': [8],
#  'muscle pain': [8],
#  'soreness': [8],
#  'pain in calf': [8],
#  'strain of neck muscle': [8],
#  'strain of back muscle': [8],
#  'polymyalgia': [8],
#  'strain of tendon of medial thigh muscle': [8],
#  'strain of abdominal muscle': [8],
#  'strain of calf muscle': [8],
#  'skeletal muscle tender': [8],
#  'primary fibromyalgia syndrome': [8],
#  'strain of trapezius muscle': [8],
#  'strain of left trapezius muscle': [8],
#  'strain of right trapezius muscle': [8],
#  'myalgia of pelvic floor': [8],
#  'strain of flexor muscle of right hip': [8],
#  'gastroesophageal reflux disease': [9],
#  'heartburn': [9],
#  'reflux': [9],
#  'laryngopharyngeal reflux': [9],
#  'gastroesophageal reflux disease with hiatal hernia': [9],
#  'acid reflux': [9],
#  'chronic cough': [10],
#  'decreased coughing': [10],
#  'paroxysmal cough': [10],
#  'nocturnal cough': [10],
#  'cough after eating': [10],
#  'barking cough': [10],
#  'hacking cough': [10],
#  'productive cough': [10],
#  'morning cough': [10],
#  'spasmodic cough': [10],
#  'psychogenic cough': [10],
#  'painful cough': [10],
#  'unable to cough': [10],
#  'coughing ineffective': [10],
#  'persistent cough': [10],
#  'difficulty coughing': [10],
#  'increasing frequency of cough': [10],
#  'allergic cough': [10],
#  'effective cough': [10],
#  'cough on exercise': [10],
#  'does cough': [10],
#  'cough variant asthma': [10],
#  'dry cough': [10],
#  'coughing up phlegm': [10],
#  'cough strength': [10],
#  'backache': [11],
#  'low back pain': [11],
#  'sciatica': [11],
#  'pain in spine': [11],
#  'pain in cervical spine': [11],
#  'acute back pain with sciatica': [11],
#  'pain in lumbar spine': [11],
#  'mechanical low back pain': [11],
#  'thoracic back pain': [11],
#  'acute thoracic back pain': [11],
#  'sacral back pain': [11],
#  'c/o - low back pain': [11],
#  'chronic low back pain': [11],
#  'acute low back pain': [11],
#  'renal pain': [11],
#  'pain in thoracic spine': [11],
#  'acute back pain - unspecified': [11],
#  'chronic back pain': [11],
#  'bilateral sciatica': [11],
#  'right side sciatica': [11],
#  'left side sciatica': [11],
#  'chronic thoracic back pain': [11],
#  'lumbar discogenic pain': [11],
#  'intractable low back pain': [11],
#  'posttraumatic stress disorder': [12],
#  'psychological stress': [12],
#  'emotional stress': [12],
#  'increased stress': [12],
#  'acute stress disorder': [12],
#  'stress and adjustment reaction': [12],
#  'stress at work': [12],
#  'chronic post-traumatic stress disorder': [12],
#  'work stress (finding)': [12],
#  'relapsing fever': [13],
#  'fever with chills': [13],
#  'low grade pyrexia': [13],
#  'intermittent fever': [13],
#  'feels hot/feverish': [13],
#  'fever symptoms': [13],
#  'continuous fever': [13],
#  'prolonged fever': [13],
#  'spiking fever': [13],
#  'feeling feverish': [13],
#  'disorder characterized by fever': [13],
#  'cough with fever': [13],
#  'localized edema': [14],
#  'soft tissue swelling': [14],
#  'dental swelling': [14],
#  'mucous membrane swelling': [14],
#  'swelling of nipple': [14],
#  'swelling of skin': [14],
#  'swelling of scrotum': [14],
#  'chest swelling': [14],
#  'sensation of swelling': [14],
#  'orbital swelling': [14],
#  'swelling or edema': [14],
#  'swelling of inguinal region': [14],
#  'localized swelling, mass and lump, neck': [14],
#  'localized swelling, mass and lump, trunk': [14],
#  'edematous skin': [14],
#  'swelling of labia': [14],
#  'swelling of ankle joint': [14],
#  'neck swelling': [14],
#  'swelling of buttock': [14],
#  'swelling of head': [14],
#  'localized swelling': [14],
#  'penile swelling': [14],
#  'intracranial swelling': [14],
#  'swelling of testicle': [14],
#  'localized swelling of abdominal wall': [14],
#  'blood coagulation disorder': [15],
#  'bleeding gums': [15],
#  'hematoma': [15],
#  'hemorrhage': [15],
#  'hemorrhage of rectum and anus': [15],
#  'bleeding from mouth': [15],
#  'retroperitoneal hemorrhage': [15],
#  'subungual hemorrhage': [15],
#  'hemorrhage of urethra': [15],
#  'wound hemorrhage': [15],
#  'capillary hemorrhage': [15],
#  'bleeding hemorrhoids': [15],
#  'bleeding internal hemorrhoids': [15],
#  'bleeding from ear': [15],
#  'acute hemorrhage': [15],
#  'chronic hemorrhage': [15],
#  'massive hemorrhage': [15],
#  'diffuse hemorrhage': [15],
#  'splinter hemorrhage': [15],
#  'dissecting hemorrhage': [15],
#  'arterial hemorrhage': [15],
#  'venous hemorrhage': [15],
#  'secondary hemorrhage': [15],
#  'bleeds profusely': [15],
#  'bleeding from anus': [15],
#  'bleeding cervix': [15],
#  'bleeding skin': [15],
#  'painless rectal bleeding': [15],
#  'break-through bleeding': [93, 15],
#  'bleeding requiring transfusion': [15],
#  'cachexia': [16],
#  'underweight': [16],
#  'abnormal weight loss': [16],
#  'weight decreasing': [16],
#  'intentional weight loss': [16],
#  'unexplained weight loss': [16],
#  'recent weight loss': [16],
#  'unintentional weight loss': [16],
#  'abdominal cramps': [0, 17],
#  'flatulence, eructation and gas pain': [17],
#  'biliary colic': [17],
#  'stomach ache': [17],
#  'pain in esophagus': [17],
#  'abdominal discomfort': [17],
#  'chronic abdominal pain': [17],
#  'upper abdominal pain': [17],
#  'epigastric pain': [17],
#  'burning epigastric pain': [17],
#  'lower abdominal pain': [17],
#  'umbilical pain': [17],
#  'right upper quadrant pain': [17],
#  'upset stomach': [17],
#  'left lower quadrant pain': [17],
#  'left upper quadrant pain': [17],
#  'generalized abdominal pain': [17],
#  'stomach cramps': [17],
#  'right flank pain': [17],
#  'left flank pain': [17],
#  'central abdominal pain': [17],
#  'abdominal wind pain': [17],
#  'localized abdominal pain': [17],
#  'liver pain': [17],
#  'pancreatic pain': [17],
#  'left sided abdominal pain': [17],
#  'right sided abdominal pain': [17],
#  'abdominal wall pain': [17],
#  'hunger pain': [17],
#  'nonspecific abdominal pain': [17],
#  'right lower quadrant pain': [17],
#  'acute abdominal pain': [17],
#  'periumbilical pain': [17],
#  'abdominal pain - cause unknown': [17],
#  'epigastric discomfort': [17],
#  'recurrent abdominal pain': [17],
#  'visceral abdominal pain': [17],
#  'intractable abdominal pain': [17],
#  'dizziness': [18],
#  'vertigo': [18],
#  'peripheral vertigo': [18],
#  'benign paroxysmal positional vertigo': [18],
#  'vertigo of central origin': [18],
#  'lightheadedness': [18],
#  'postural dizziness': [18],
#  'labyrinthine vertigo': [18],
#  'migrainous vertigo': [18],
#  'dizziness and giddiness': [18],
#  'positional vertigo': [18],
#  'paroxysmal vertigo': [18],
#  'intermittent vertigo': [18],
#  'constant vertigo': [18],
#  'severe vertigo': [18],
#  'chronic vertigo': [18],
#  'epidemic vertigo': [18],
#  'dizzy spells': [18],
#  'angina pectoris': [19],
#  'pleuritic pain': [19],
#  'chest wall pain': [19],
#  'other chest pain': [19],
#  'dull chest pain': [19],
#  'chest pain on exertion': [19],
#  'radiating chest pain': [19],
#  'crushing chest pain': [19],
#  'atypical chest pain': [19],
#  'stable angina': [19],
#  'chest pain at rest': [19],
#  'central chest pain': [19],
#  'cardiac chest pain': [19],
#  'left subcostal pain': [19],
#  'chest pain on breathing': [19],
#  'anterior chest wall pain': [19],
#  'musculoskeletal chest pain': [19],
#  'non-cardiac chest pain': [19],
#  'acute chest pain': [19],
#  'left sided chest pain': [19],
#  'right sided chest pain': [19],
#  'upper chest pain': [19],
#  'pain of intercostal space': [19],
#  'squeezing chest pain': [19],
#  'chronic chest pain': [19],
#  'asthenia': [20],
#  'weakness present': [20],
#  'o/e - paresis (weakness)': [20],
#  'chronic constipation with overflow': [21],
#  'chronic idiopathic constipation': [21],
#  'constipation - functional': [21],
#  'acute constipation': [21],
#  'chronic constipation': [21],
#  'slow transit constipation': [21],
#  'blister': [22],
#  'telangiectasis': [22],
#  'lesion of penis': [22],
#  'peeling of skin': [22],
#  'lesion of skin of nose': [22],
#  'pustule': [22],
#  'pigmented skin lesion': [22],
#  'injury of integument': [22],
#  'macule': [22],
#  'blistering eruption': [22],
#  'lesion of neck': [22],
#  'lesion of nose': [22],
#  'lesion of lip': [22],
#  'lesion of eyelid': [22],
#  'lesion of face': [22],
#  'lesion of skin of face': [22],
#  'spots on skin': [22],
#  'tear of skin': [22],
#  'circumscribed lesion': [22],
#  'abrasion': [22],
#  'exfoliative lesion': [22],
#  'papule of skin': [22],
#  'lesion of skin of breast': [22],
#  'lesion of left upper eyelid': [22],
#  'lesion of lower eyelid': [22],
#  'lesion of left lower eyelid': [22],
#  'ear lesion': [22],
#  'lesion of scalp': [22],
#  'lesion of upper eyelid': [22],
#  'lesion of skin of foot': [22],
#  'blister of skin': [22],
#  'lesion of skin of left ear': [22],
#  'sore on skin': [22],
#  'vesicle of skin': [22],
#  'erosion of skin': [22],
#  'atypical pigmented lesion': [22],
#  'lesion of left eyelid': [22],
#  'lesion of left ear': [22],
#  'wheeze - rhonchi': [23],
#  'inspiratory wheezing': [23],
#  'expiratory wheezing': [23],
#  'eruption': [24],
#  'pruritic rash': [24],
#  'serum rash': [24],
#  'acute febrile neutrophilic dermatosis': [24],
#  'pustular rash': [24],
#  'purpuric rash': [24],
#  'lichenoid eruption': [24],
#  'acneiform eruption': [24],
#  'macular rash': [24],
#  'erythematous rash': [24],
#  'rash of groin': [24],
#  'rash of scalp': [24],
#  'vesicular eruption': [24],
#  'butterfly rash': [24],
#  'maculopapular rash': [24],
#  'c/o: a rash': [24],
#  'localized eruption of skin': [24],
#  'generalized rash': [24],
#  'psoriasiform rash': [24],
#  'blanching rash': [24],
#  'pustular eruption': [24],
#  'eruption of skin present': [24],
#  'insomnia disorder related to known organic factor': [25],
#  'primary insomnia': [25],
#  'sleep deprivation': [25],
#  'disturbance in sleep behavior': [25],
#  'sleep pattern disturbance': [25],
#  'insomnia with sleep apnea': [25],
#  'restless sleep': [25],
#  'difficulty sleeping': [25],
#  'persistent insomnia': [25],
#  'initial insomnia': [25],
#  'middle insomnia': [25],
#  'sleep-wake schedule disorder, delayed phase type': [25],
#  'sleep related bruxism': [25],
#  'cannot sleep at all': [25],
#  'not getting enough sleep': [25],
#  'terminal insomnia': [25],
#  'chronic insomnia': [25],
#  'inadequate sleep hygiene': [25],
#  'poor sleep pattern': [25],
#  'adjustment insomnia': [25],
#  'organic sleep disorder': [25],
#  'insomnia due to anxiety and fear': [25],
#  'foot pain': [26],
#  'pain in lower limb': [26],
#  'pain in limb': [26],
#  'pain in wrist': [26],
#  'heel pain': [26],
#  'plantar heel pain': [26],
#  'posterior heel pain': [26],
#  'pain in elbow': [26],
#  'pain in upper limb': [26],
#  'pain in finger': [26],
#  'pain in forearm': [26],
#  'hand pain': [26],
#  'thigh pain': [26],
#  'pain in thumb': [26],
#  'pain in toe': [26],
#  'pain in left arm': [26],
#  'pain in right arm': [26],
#  'pain in left lower limb': [26],
#  'pain in right lower limb': [26],
#  'pain radiating to right shoulder': [26],
#  'pain in right foot': [26],
#  'pain in bilateral lower legs': [26],
#  'bilateral calf pain': [26],
#  'pain of left upper arm': [26],
#  'pain of left heel': [26],
#  'pain of left hand': [26],
#  'pain of left calf': [26],
#  'pain of right upper arm': [26],
#  'pain in right heel': [26],
#  'pain in right hand': [26],
#  'pain of right calf': [26],
#  'pain of right forearm': [26],
#  'pain of left forearm': [26],
#  'pain in both feet': [26],
#  'pain in left foot': [26],
#  'pain of left wrist': [26],
#  'pain of right wrist': [26],
#  'pain of left thigh': [26],
#  'chronic ankle pain': [26],
#  'pain due to varicose veins of lower extremity': [26],
#  'bilateral thumb pain': [26],
#  'bilateral wrist pain': [26],
#  'bilateral heel pain': [26],
#  'pain of toe of left foot': [26],
#  'pain of toe of right foot': [26],
#  'pain in finger of left hand': [26],
#  'pain of left lower leg': [26],
#  'pain of right lower leg': [26],
#  'formication': [27],
#  ...}

# %%
#### checking the synonyms mapped to multiple symptoms at once to see if we can map them to single symptom
for (k, v) in lexicon_symptoms_dict.items():
    if type(v) == list and len(v)>1:
        print('Symptom synonym: ' + str(k))
        print('Original symptoms mapped to this symptom: ')
        [print(basic_symptom_list[e]) for e in v]
# Out:
# Symptom synonym: swelling
# Original symptoms mapped to this symptom:
# edema
# swelling
# Symptom synonym: abnormal breathing
# Original symptoms mapped to this symptom:
# abnormal breathing
# shortness of breath
# Symptom synonym: cramping
# Original symptoms mapped to this symptom:
# muscle cramps
# cramping
# Symptom synonym: ulcer
# Original symptoms mapped to this symptom:
# ulcer
# skin lesion
# Symptom synonym: spasm
# Original symptoms mapped to this symptom:
# spasm
# muscle cramps
# Symptom synonym: tenderness
# Original symptoms mapped to this symptom:
# myalgia
# tenderness
# Symptom synonym: muscle cramps
# Original symptoms mapped to this symptom:
# spasm
# muscle cramps
# Symptom synonym: loss of consciousness
# Original symptoms mapped to this symptom:
# mental status change
# loss of consciousness
# Symptom synonym: menstrual spotting
# Original symptoms mapped to this symptom:
# vaginal bleeding
# menstrual spotting
# Symptom synonym: restlessness
# Original symptoms mapped to this symptom:
# restlessness
# psychomotor agitation
# agitation
# Symptom synonym: psychomotor agitation
# Original symptoms mapped to this symptom:
# psychomotor agitation
# agitation
# Symptom synonym: disorientation
# Original symptoms mapped to this symptom:
# disorientation
# confusion
# Symptom synonym: feeling bad
# Original symptoms mapped to this symptom:
# fatigue
# feeling bad
# Symptom synonym: muscle strain
# Original symptoms mapped to this symptom:
# myalgia
# muscle strain
# Symptom synonym: twitching
# Original symptoms mapped to this symptom:
# muscle twitching
# twitching
# Symptom synonym: lymphedema
# Original symptoms mapped to this symptom:
# lymphedema
# peripheral edema
# Symptom synonym: flank pain
# Original symptoms mapped to this symptom:
# back pain
# flank pain
# Symptom synonym: throat swelling
# Original symptoms mapped to this symptom:
# throat swelling
# oropharyngeal swelling
# Symptom synonym: mania nos
# Original symptoms mapped to this symptom:
# mania
# mania nos
# Symptom synonym: oliguria
# Original symptoms mapped to this symptom:
# lower urinary tract symptoms
# oliguria
# Symptom synonym: muscle spasms
# Original symptoms mapped to this symptom:
# muscle spasms
# hyperactivity
# spasm
# Symptom synonym: dysesthesia
# Original symptoms mapped to this symptom:
# burning sensation
# dysesthesia
# Symptom synonym: eye swelling
# Original symptoms mapped to this symptom:
# eye swelling
# ocular edema
# Symptom synonym: jaw pain
# Original symptoms mapped to this symptom:
# jaw pain
# facial pain
# Symptom synonym: neuropathic pain
# Original symptoms mapped to this symptom:
# pain
# neuralgia
# neuropathic pain
# Symptom synonym: mania
# Original symptoms mapped to this symptom:
# mania
# manic mood
# Symptom synonym: hyperthermia
# Original symptoms mapped to this symptom:
# hyperthermia
# fever
# Symptom synonym: facial swelling
# Original symptoms mapped to this symptom:
# facial swelling
# facial edema
# swelling
# Symptom synonym: dry eyes
# Original symptoms mapped to this symptom:
# dry eyes
# keratoconjunctivitis sicca
# Symptom synonym: dull pain
# Original symptoms mapped to this symptom:
# pain
# chest pain
# Symptom synonym: neurotic depression
# Original symptoms mapped to this symptom:
# depression
# dysthymia
# Symptom synonym: break-through bleeding
# Original symptoms mapped to this symptom:
# vaginal bleeding
# bleeding
# Symptom synonym: abdominal cramps
# Original symptoms mapped to this symptom:
# pain
# abdominal pain
# Symptom synonym: numbness
# Original symptoms mapped to this symptom:
# paresthesia
# hypesthesia
# Symptom synonym: decreased urine output
# Original symptoms mapped to this symptom:
# lower urinary tract symptoms
# oliguria
# Symptom synonym: respiratory arrest
# Original symptoms mapped to this symptom:
# respiratory depression
# sleep apnea
# Symptom synonym: rigor
# Original symptoms mapped to this symptom:
# chills
# muscle stiffness
# Symptom synonym: confusional state
# Original symptoms mapped to this symptom:
# mental status change
# confusion
# Symptom synonym: collapse
# Original symptoms mapped to this symptom:
# anaphylaxis
# syncope
# Symptom synonym: hematochezia
# Original symptoms mapped to this symptom:
# gastrointestinal hemorrhage
# blood in stools
# Symptom synonym: melena
# Original symptoms mapped to this symptom:
# gastrointestinal hemorrhage
# blood in stools
# Symptom synonym: sinus pain
# Original symptoms mapped to this symptom:
# headaches
# facial pain
# Symptom synonym: ulceration
# Original symptoms mapped to this symptom:
# ulcer
# skin lesion
# Symptom synonym: myofascial pain
# Original symptoms mapped to this symptom:
# myalgia
# musculoskeletal pain
# Symptom synonym: blood in stool
# Original symptoms mapped to this symptom:
# gastrointestinal hemorrhage
# blood in stools
# Symptom synonym: dysphonia
# Original symptoms mapped to this symptom:
# difficulty speaking
# hoarseness
# Symptom synonym: motor restlessness
# Original symptoms mapped to this symptom:
# restlessness
# akathisia
# Symptom synonym: crampy abdominal pain
# Original symptoms mapped to this symptom:
# pain
# abdominal pain
# Symptom synonym: oral pain
# Original symptoms mapped to this symptom:
# pain
# facial pain
# Symptom synonym: depressive neurosis
# Original symptoms mapped to this symptom:
# depression
# dysthymia
# Symptom synonym: feel bad
# Original symptoms mapped to this symptom:
# fatigue
# feeling bad
# Symptom synonym: feel ill
# Original symptoms mapped to this symptom:
# fatigue
# feeling bad
# Symptom synonym: breathing difficulties
# Original symptoms mapped to this symptom:
# respiratory depression
# shortness of breath
# Symptom synonym: difficulty breathing
# Original symptoms mapped to this symptom:
# respiratory depression
# shortness of breath
# Symptom synonym: respiratory difficulties
# Original symptoms mapped to this symptom:
# respiratory depression
# shortness of breath
# Symptom synonym: vomiting blood
# Original symptoms mapped to this symptom:
# gastrointestinal hemorrhage
# nausea and/or vomiting
# Symptom synonym: facial puffiness
# Original symptoms mapped to this symptom:
# facial edema
# swelling
# Symptom synonym: bleeding breakthrough
# Original symptoms mapped to this symptom:
# vaginal bleeding
# bleeding
# Symptom synonym: bleeding diathesis
# Original symptoms mapped to this symptom:
# tendency to bleed
# bleeding
# Symptom synonym: bleeding disorder
# Original symptoms mapped to this symptom:
# tendency to bleed
# bleeding
# Symptom synonym: bleeding disorders
# Original symptoms mapped to this symptom:
# tendency to bleed
# bleeding
# Symptom synonym: bleeding tendency
# Original symptoms mapped to this symptom:
# tendency to bleed
# bleeding
# Symptom synonym: breakthrough bleeding
# Original symptoms mapped to this symptom:
# vaginal bleeding
# bleeding
# Symptom synonym: intermenstrual bleeding
# Original symptoms mapped to this symptom:
# vaginal bleeding
# bleeding
# Symptom synonym: spotting between menses
# Original symptoms mapped to this symptom:
# vaginal bleeding
# bleeding
# Symptom synonym: wooziness
# Original symptoms mapped to this symptom:
# dizziness or vertigo
# clouded consciousness
# Symptom synonym: paresis
# Original symptoms mapped to this symptom:
# muscle weakness
# weakness
# Symptom synonym: peeling
# Original symptoms mapped to this symptom:
# skin irritation
# skin lesion
# Symptom synonym: skin breakdown
# Original symptoms mapped to this symptom:
# impaired skin integrity
# skin lesion
# Symptom synonym: spots
# Original symptoms mapped to this symptom:
# rash
# skin lesion
# Symptom synonym: ulcerated
# Original symptoms mapped to this symptom:
# ulcer
# skin lesion
# Symptom synonym: ulcerating
# Original symptoms mapped to this symptom:
# ulcer
# skin lesion
# Symptom synonym: ulceration, nos
# Original symptoms mapped to this symptom:
# ulcer
# skin lesion
# Symptom synonym: disturbances, sleep
# Original symptoms mapped to this symptom:
# insomnia
# sleep disorder
# Symptom synonym: sleep disturbance
# Original symptoms mapped to this symptom:
# insomnia
# sleep disorder
# Symptom synonym: sleep disturbances
# Original symptoms mapped to this symptom:
# insomnia
# sleep disorder
# Symptom synonym: acquired lymphedema
# Original symptoms mapped to this symptom:
# lymphedema
# peripheral edema
# Symptom synonym: acquired lymphoedema
# Original symptoms mapped to this symptom:
# lymphedema
# peripheral edema
# Symptom synonym: urine output decreased
# Original symptoms mapped to this symptom:
# lower urinary tract symptoms
# oliguria
# Symptom synonym: urine output low
# Original symptoms mapped to this symptom:
# lower urinary tract symptoms
# oliguria
# Symptom synonym: urine production scanty
# Original symptoms mapped to this symptom:
# lower urinary tract symptoms
# oliguria
# Symptom synonym: urine volume deficient
# Original symptoms mapped to this symptom:
# lower urinary tract symptoms
# oliguria
# Symptom synonym: volume urine decreased
# Original symptoms mapped to this symptom:
# lower urinary tract symptoms
# oliguria
# Symptom synonym: excess fluid
# Original symptoms mapped to this symptom:
# edema
# fluid retention
# Symptom synonym: blocked nose
# Original symptoms mapped to this symptom:
# sinonasal congestion
# nasal obstruction
# Symptom synonym: difficulties gait
# Original symptoms mapped to this symptom:
# walking disability
# abnormal gait
# Symptom synonym: gait difficulty
# Original symptoms mapped to this symptom:
# walking disability
# abnormal gait
# Symptom synonym: limited mobility
# Original symptoms mapped to this symptom:
# reduced mobility
# abnormal gait
# Symptom synonym: pulmonary arrest
# Original symptoms mapped to this symptom:
# respiratory depression
# sleep apnea
# Symptom synonym: loss of vision
# Original symptoms mapped to this symptom:
# visual changes
# blindness
# Symptom synonym: vision loss
# Original symptoms mapped to this symptom:
# visual changes
# blindness
# Symptom synonym: acute confusional state
# Original symptoms mapped to this symptom:
# mental status change
# confusion
# Symptom synonym: bewilderment
# Original symptoms mapped to this symptom:
# confusion
# clouded consciousness
# Symptom synonym: dazed
# Original symptoms mapped to this symptom:
# confusion
# clouded consciousness
# Symptom synonym: dazed state
# Original symptoms mapped to this symptom:
# confusion
# clouded consciousness
# Symptom synonym: muddled
# Original symptoms mapped to this symptom:
# confusion
# clouded consciousness
# Symptom synonym: blackout
# Original symptoms mapped to this symptom:
# loss of consciousness
# syncope
# Symptom synonym: pass out
# Original symptoms mapped to this symptom:
# loss of consciousness
# syncope
# Symptom synonym: passed out
# Original symptoms mapped to this symptom:
# loss of consciousness
# syncope
# Symptom synonym: passing out
# Original symptoms mapped to this symptom:
# mental status change
# syncope
# Symptom synonym: black faeces
# Original symptoms mapped to this symptom:
# gastrointestinal hemorrhage
# feces color: tarry
# Symptom synonym: black faeces symptom
# Original symptoms mapped to this symptom:
# gastrointestinal hemorrhage
# feces color: tarry
# Symptom synonym: black feces
# Original symptoms mapped to this symptom:
# gastrointestinal hemorrhage
# feces color: tarry
# Symptom synonym: black feces symptom
# Original symptoms mapped to this symptom:
# gastrointestinal hemorrhage
# feces color: tarry
# Symptom synonym: black stool
# Original symptoms mapped to this symptom:
# gastrointestinal hemorrhage
# feces color: tarry
# Symptom synonym: black stools
# Original symptoms mapped to this symptom:
# gastrointestinal hemorrhage
# feces color: tarry
# Symptom synonym: blood in faeces
# Original symptoms mapped to this symptom:
# gastrointestinal hemorrhage
# blood in stools
# Symptom synonym: blood in feces
# Original symptoms mapped to this symptom:
# gastrointestinal hemorrhage
# blood in stools
# Symptom synonym: bloody stool
# Original symptoms mapped to this symptom:
# gastrointestinal hemorrhage
# blood in stools
# Symptom synonym: dark stools
# Original symptoms mapped to this symptom:
# gastrointestinal hemorrhage
# feces color: tarry
# Symptom synonym: faeces: blood
# Original symptoms mapped to this symptom:
# gastrointestinal hemorrhage
# blood in stools
# Symptom synonym: feces: blood
# Original symptoms mapped to this symptom:
# gastrointestinal hemorrhage
# blood in stools
# Symptom synonym: haematochezia
# Original symptoms mapped to this symptom:
# gastrointestinal hemorrhage
# blood in stools
# Symptom synonym: melaena
# Original symptoms mapped to this symptom:
# gastrointestinal hemorrhage
# blood in stools
# Symptom synonym: passage of bloody stools
# Original symptoms mapped to this symptom:
# gastrointestinal hemorrhage
# blood in stools
# Symptom synonym: stool black
# Original symptoms mapped to this symptom:
# gastrointestinal hemorrhage
# feces color: tarry
# Symptom synonym: stool tarry
# Original symptoms mapped to this symptom:
# gastrointestinal hemorrhage
# feces color: tarry
# Symptom synonym: tarry stool
# Original symptoms mapped to this symptom:
# gastrointestinal hemorrhage
# feces color: tarry
# Symptom synonym: tarry stools
# Original symptoms mapped to this symptom:
# gastrointestinal hemorrhage
# feces color: tarry
# Symptom synonym: excessive overactivity
# Original symptoms mapped to this symptom:
# psychomotor agitation
# agitation
# Symptom synonym: excessive overactivity, nos
# Original symptoms mapped to this symptom:
# psychomotor agitation
# agitation
# Symptom synonym: increased purposeless goalless activity
# Original symptoms mapped to this symptom:
# psychomotor agitation
# agitation
# Symptom synonym: increased purposeless goalless activity, nos
# Original symptoms mapped to this symptom:
# psychomotor agitation
# agitation
# Symptom synonym: restless
# Original symptoms mapped to this symptom:
# restlessness
# agitation
# Symptom synonym: restlessness marked
# Original symptoms mapped to this symptom:
# restlessness
# agitation
# Symptom synonym: unable to keep still
# Original symptoms mapped to this symptom:
# restlessness
# agitation
# Symptom synonym: hair thinning
# Original symptoms mapped to this symptom:
# hair loss
# hypotrichosis
# Symptom synonym: affective psychosis nos
# Original symptoms mapped to this symptom:
# psychosis
# mood swings
# Symptom synonym: muscle spasm
# Original symptoms mapped to this symptom:
# spasm
# myotonia
# Symptom synonym: dysfunctional uterine bleeding
# Original symptoms mapped to this symptom:
# abnormal uterine bleeding
# vaginal bleeding
# Symptom synonym: spotting
# Original symptoms mapped to this symptom:
# vaginal bleeding
# menstrual spotting
# Symptom synonym: cold feel
# Original symptoms mapped to this symptom:
# temperature intolerance
# feels cold
# Symptom synonym: cold feelings
# Original symptoms mapped to this symptom:
# temperature intolerance
# feels cold
# Symptom synonym: feel cold
# Original symptoms mapped to this symptom:
# temperature intolerance
# feels cold
# Symptom synonym: jerk
# Original symptoms mapped to this symptom:
# muscle twitching
# twitching
# Symptom synonym: jerking
# Original symptoms mapped to this symptom:
# muscle twitching
# twitching
# Symptom synonym: manic
# Original symptoms mapped to this symptom:
# mania
# manic mood
# Symptom synonym: swollen throat
# Original symptoms mapped to this symptom:
# throat swelling
# oropharyngeal swelling

# %%
#### associating the same words together
#### e.g.: 'swelling' is mapped to edema and swelling, we map it to only swelling
for (k, v) in lexicon_symptoms_dict.items():
    for e in v:
        if lexicon['symptom'][e] == k:
            lexicon_symptoms_dict[k] = [e]
            break

# %%
#### checking the synonyms mapped to multiple symptoms at once to see if we can map them to single symptom
for (k, v) in lexicon_symptoms_dict.items():
    if type(v) == list and len(v)>1:
        print('Symptom synonym: ' + str(k))
        print('Original symptoms mapped to this symptom: ')
        [print(basic_symptom_list[e]) for e in v]
# Out:
# Symptom synonym: dull pain
# Original symptoms mapped to this symptom:
# pain
# chest pain
# Symptom synonym: neurotic depression
# Original symptoms mapped to this symptom:
# depression
# dysthymia
# Symptom synonym: break-through bleeding
# Original symptoms mapped to this symptom:
# vaginal bleeding
# bleeding
# Symptom synonym: abdominal cramps
# Original symptoms mapped to this symptom:
# pain
# abdominal pain
# Symptom synonym: numbness
# Original symptoms mapped to this symptom:
# paresthesia
# hypesthesia
# Symptom synonym: decreased urine output
# Original symptoms mapped to this symptom:
# lower urinary tract symptoms
# oliguria
# Symptom synonym: respiratory arrest
# Original symptoms mapped to this symptom:
# respiratory depression
# sleep apnea
# Symptom synonym: rigor
# Original symptoms mapped to this symptom:
# chills
# muscle stiffness
# Symptom synonym: confusional state
# Original symptoms mapped to this symptom:
# mental status change
# confusion
# Symptom synonym: collapse
# Original symptoms mapped to this symptom:
# anaphylaxis
# syncope
# Symptom synonym: hematochezia
# Original symptoms mapped to this symptom:
# gastrointestinal hemorrhage
# blood in stools
# Symptom synonym: melena
# Original symptoms mapped to this symptom:
# gastrointestinal hemorrhage
# blood in stools
# Symptom synonym: sinus pain
# Original symptoms mapped to this symptom:
# headaches
# facial pain
# Symptom synonym: ulceration
# Original symptoms mapped to this symptom:
# ulcer
# skin lesion
# Symptom synonym: myofascial pain
# Original symptoms mapped to this symptom:
# myalgia
# musculoskeletal pain
# Symptom synonym: blood in stool
# Original symptoms mapped to this symptom:
# gastrointestinal hemorrhage
# blood in stools
# Symptom synonym: dysphonia
# Original symptoms mapped to this symptom:
# difficulty speaking
# hoarseness
# Symptom synonym: motor restlessness
# Original symptoms mapped to this symptom:
# restlessness
# akathisia
# Symptom synonym: crampy abdominal pain
# Original symptoms mapped to this symptom:
# pain
# abdominal pain
# Symptom synonym: oral pain
# Original symptoms mapped to this symptom:
# pain
# facial pain
# Symptom synonym: depressive neurosis
# Original symptoms mapped to this symptom:
# depression
# dysthymia
# Symptom synonym: feel bad
# Original symptoms mapped to this symptom:
# fatigue
# feeling bad
# Symptom synonym: feel ill
# Original symptoms mapped to this symptom:
# fatigue
# feeling bad
# Symptom synonym: breathing difficulties
# Original symptoms mapped to this symptom:
# respiratory depression
# shortness of breath
# Symptom synonym: difficulty breathing
# Original symptoms mapped to this symptom:
# respiratory depression
# shortness of breath
# Symptom synonym: respiratory difficulties
# Original symptoms mapped to this symptom:
# respiratory depression
# shortness of breath
# Symptom synonym: vomiting blood
# Original symptoms mapped to this symptom:
# gastrointestinal hemorrhage
# nausea and/or vomiting
# Symptom synonym: facial puffiness
# Original symptoms mapped to this symptom:
# facial edema
# swelling
# Symptom synonym: bleeding breakthrough
# Original symptoms mapped to this symptom:
# vaginal bleeding
# bleeding
# Symptom synonym: bleeding diathesis
# Original symptoms mapped to this symptom:
# tendency to bleed
# bleeding
# Symptom synonym: bleeding disorder
# Original symptoms mapped to this symptom:
# tendency to bleed
# bleeding
# Symptom synonym: bleeding disorders
# Original symptoms mapped to this symptom:
# tendency to bleed
# bleeding
# Symptom synonym: bleeding tendency
# Original symptoms mapped to this symptom:
# tendency to bleed
# bleeding
# Symptom synonym: breakthrough bleeding
# Original symptoms mapped to this symptom:
# vaginal bleeding
# bleeding
# Symptom synonym: intermenstrual bleeding
# Original symptoms mapped to this symptom:
# vaginal bleeding
# bleeding
# Symptom synonym: spotting between menses
# Original symptoms mapped to this symptom:
# vaginal bleeding
# bleeding
# Symptom synonym: wooziness
# Original symptoms mapped to this symptom:
# dizziness or vertigo
# clouded consciousness
# Symptom synonym: paresis
# Original symptoms mapped to this symptom:
# muscle weakness
# weakness
# Symptom synonym: peeling
# Original symptoms mapped to this symptom:
# skin irritation
# skin lesion
# Symptom synonym: skin breakdown
# Original symptoms mapped to this symptom:
# impaired skin integrity
# skin lesion
# Symptom synonym: spots
# Original symptoms mapped to this symptom:
# rash
# skin lesion
# Symptom synonym: ulcerated
# Original symptoms mapped to this symptom:
# ulcer
# skin lesion
# Symptom synonym: ulcerating
# Original symptoms mapped to this symptom:
# ulcer
# skin lesion
# Symptom synonym: ulceration, nos
# Original symptoms mapped to this symptom:
# ulcer
# skin lesion
# Symptom synonym: disturbances, sleep
# Original symptoms mapped to this symptom:
# insomnia
# sleep disorder
# Symptom synonym: sleep disturbance
# Original symptoms mapped to this symptom:
# insomnia
# sleep disorder
# Symptom synonym: sleep disturbances
# Original symptoms mapped to this symptom:
# insomnia
# sleep disorder
# Symptom synonym: acquired lymphedema
# Original symptoms mapped to this symptom:
# lymphedema
# peripheral edema
# Symptom synonym: acquired lymphoedema
# Original symptoms mapped to this symptom:
# lymphedema
# peripheral edema
# Symptom synonym: urine output decreased
# Original symptoms mapped to this symptom:
# lower urinary tract symptoms
# oliguria
# Symptom synonym: urine output low
# Original symptoms mapped to this symptom:
# lower urinary tract symptoms
# oliguria
# Symptom synonym: urine production scanty
# Original symptoms mapped to this symptom:
# lower urinary tract symptoms
# oliguria
# Symptom synonym: urine volume deficient
# Original symptoms mapped to this symptom:
# lower urinary tract symptoms
# oliguria
# Symptom synonym: volume urine decreased
# Original symptoms mapped to this symptom:
# lower urinary tract symptoms
# oliguria
# Symptom synonym: excess fluid
# Original symptoms mapped to this symptom:
# edema
# fluid retention
# Symptom synonym: blocked nose
# Original symptoms mapped to this symptom:
# sinonasal congestion
# nasal obstruction
# Symptom synonym: difficulties gait
# Original symptoms mapped to this symptom:
# walking disability
# abnormal gait
# Symptom synonym: gait difficulty
# Original symptoms mapped to this symptom:
# walking disability
# abnormal gait
# Symptom synonym: limited mobility
# Original symptoms mapped to this symptom:
# reduced mobility
# abnormal gait
# Symptom synonym: pulmonary arrest
# Original symptoms mapped to this symptom:
# respiratory depression
# sleep apnea
# Symptom synonym: loss of vision
# Original symptoms mapped to this symptom:
# visual changes
# blindness
# Symptom synonym: vision loss
# Original symptoms mapped to this symptom:
# visual changes
# blindness
# Symptom synonym: acute confusional state
# Original symptoms mapped to this symptom:
# mental status change
# confusion
# Symptom synonym: bewilderment
# Original symptoms mapped to this symptom:
# confusion
# clouded consciousness
# Symptom synonym: dazed
# Original symptoms mapped to this symptom:
# confusion
# clouded consciousness
# Symptom synonym: dazed state
# Original symptoms mapped to this symptom:
# confusion
# clouded consciousness
# Symptom synonym: muddled
# Original symptoms mapped to this symptom:
# confusion
# clouded consciousness
# Symptom synonym: blackout
# Original symptoms mapped to this symptom:
# loss of consciousness
# syncope
# Symptom synonym: pass out
# Original symptoms mapped to this symptom:
# loss of consciousness
# syncope
# Symptom synonym: passed out
# Original symptoms mapped to this symptom:
# loss of consciousness
# syncope
# Symptom synonym: passing out
# Original symptoms mapped to this symptom:
# mental status change
# syncope
# Symptom synonym: black faeces
# Original symptoms mapped to this symptom:
# gastrointestinal hemorrhage
# feces color: tarry
# Symptom synonym: black faeces symptom
# Original symptoms mapped to this symptom:
# gastrointestinal hemorrhage
# feces color: tarry
# Symptom synonym: black feces
# Original symptoms mapped to this symptom:
# gastrointestinal hemorrhage
# feces color: tarry
# Symptom synonym: black feces symptom
# Original symptoms mapped to this symptom:
# gastrointestinal hemorrhage
# feces color: tarry
# Symptom synonym: black stool
# Original symptoms mapped to this symptom:
# gastrointestinal hemorrhage
# feces color: tarry
# Symptom synonym: black stools
# Original symptoms mapped to this symptom:
# gastrointestinal hemorrhage
# feces color: tarry
# Symptom synonym: blood in faeces
# Original symptoms mapped to this symptom:
# gastrointestinal hemorrhage
# blood in stools
# Symptom synonym: blood in feces
# Original symptoms mapped to this symptom:
# gastrointestinal hemorrhage
# blood in stools
# Symptom synonym: bloody stool
# Original symptoms mapped to this symptom:
# gastrointestinal hemorrhage
# blood in stools
# Symptom synonym: dark stools
# Original symptoms mapped to this symptom:
# gastrointestinal hemorrhage
# feces color: tarry
# Symptom synonym: faeces: blood
# Original symptoms mapped to this symptom:
# gastrointestinal hemorrhage
# blood in stools
# Symptom synonym: feces: blood
# Original symptoms mapped to this symptom:
# gastrointestinal hemorrhage
# blood in stools
# Symptom synonym: haematochezia
# Original symptoms mapped to this symptom:
# gastrointestinal hemorrhage
# blood in stools
# Symptom synonym: melaena
# Original symptoms mapped to this symptom:
# gastrointestinal hemorrhage
# blood in stools
# Symptom synonym: passage of bloody stools
# Original symptoms mapped to this symptom:
# gastrointestinal hemorrhage
# blood in stools
# Symptom synonym: stool black
# Original symptoms mapped to this symptom:
# gastrointestinal hemorrhage
# feces color: tarry
# Symptom synonym: stool tarry
# Original symptoms mapped to this symptom:
# gastrointestinal hemorrhage
# feces color: tarry
# Symptom synonym: tarry stool
# Original symptoms mapped to this symptom:
# gastrointestinal hemorrhage
# feces color: tarry
# Symptom synonym: tarry stools
# Original symptoms mapped to this symptom:
# gastrointestinal hemorrhage
# feces color: tarry
# Symptom synonym: excessive overactivity
# Original symptoms mapped to this symptom:
# psychomotor agitation
# agitation
# Symptom synonym: excessive overactivity, nos
# Original symptoms mapped to this symptom:
# psychomotor agitation
# agitation
# Symptom synonym: increased purposeless goalless activity
# Original symptoms mapped to this symptom:
# psychomotor agitation
# agitation
# Symptom synonym: increased purposeless goalless activity, nos
# Original symptoms mapped to this symptom:
# psychomotor agitation
# agitation
# Symptom synonym: restless
# Original symptoms mapped to this symptom:
# restlessness
# agitation
# Symptom synonym: restlessness marked
# Original symptoms mapped to this symptom:
# restlessness
# agitation
# Symptom synonym: unable to keep still
# Original symptoms mapped to this symptom:
# restlessness
# agitation
# Symptom synonym: hair thinning
# Original symptoms mapped to this symptom:
# hair loss
# hypotrichosis
# Symptom synonym: affective psychosis nos
# Original symptoms mapped to this symptom:
# psychosis
# mood swings
# Symptom synonym: muscle spasm
# Original symptoms mapped to this symptom:
# spasm
# myotonia
# Symptom synonym: dysfunctional uterine bleeding
# Original symptoms mapped to this symptom:
# abnormal uterine bleeding
# vaginal bleeding
# Symptom synonym: spotting
# Original symptoms mapped to this symptom:
# vaginal bleeding
# menstrual spotting
# Symptom synonym: cold feel
# Original symptoms mapped to this symptom:
# temperature intolerance
# feels cold
# Symptom synonym: cold feelings
# Original symptoms mapped to this symptom:
# temperature intolerance
# feels cold
# Symptom synonym: feel cold
# Original symptoms mapped to this symptom:
# temperature intolerance
# feels cold
# Symptom synonym: jerk
# Original symptoms mapped to this symptom:
# muscle twitching
# twitching
# Symptom synonym: jerking
# Original symptoms mapped to this symptom:
# muscle twitching
# twitching
# Symptom synonym: manic
# Original symptoms mapped to this symptom:
# mania
# manic mood
# Symptom synonym: swollen throat
# Original symptoms mapped to this symptom:
# throat swelling
# oropharyngeal swelling

# %%
lexicon['symptom'][280]
# Out:
# 'throat swelling'

# %%
#### for the remaining synonyms we keep the closest associated symptom in meaning to avoid confusion

lexicon_symptoms_dict['dull pain'] = [0] #pain instead of chest pain
lexicon_symptoms_dict['neurotic depression'] = [2] #depression instead of dysthymia
lexicon_symptoms_dict['break-through bleeding'] = [93] #vaginal bleeding instead of bleeding
lexicon_symptoms_dict['abdominal cramps'] = [17] #abdominal pain instead of pain
lexicon_symptoms_dict['numbness'] = [165] #hypesthesia instead of paresthesia
lexicon_symptoms_dict['decreased urine output'] = [301] #oliguria instad of lower urinary tract symptoms
lexicon_symptoms_dict['respiratory arrest'] = [40] #respiratory depression instead of sleep apnea
lexicon_symptoms_dict['rigor'] = [42] #chills instead of muscle stiffness
lexicon_symptoms_dict['confusional state'] = [45] #confusion instead of mental status change
lexicon_symptoms_dict['collapse'] = [52] #syncope instead of anaphylaxis
lexicon_symptoms_dict['hematochezia'] = [64] #gastrointestinal hemorrhage instead of blood in stools
lexicon_symptoms_dict['melena'] = [99] #blood in stools instead of gastrointestinal hemorrhage
lexicon_symptoms_dict['sinus pain'] = [79] #facial pain instead of headaches
lexicon_symptoms_dict['ulceration'] = [22] #skin lesion instead of ulcer 
lexicon_symptoms_dict['myofascial pain'] = [8] #myalgia instead of musculoskeletal pain
lexicon_symptoms_dict['blood in stool'] = [99] #blood in stools instead of gastrointestinal hemorrhage
lexicon_symptoms_dict['dysphonia'] = [119] #hoarseness instead of difficulty speaking 
lexicon_symptoms_dict['motor restlessness'] = [305] #akathisia instead of restlessness
lexicon_symptoms_dict['crampy abdominal pain'] = [17] #abdominal pain instead of pain
lexicon_symptoms_dict['oral pain'] = [0] #pain instead of facial pain
lexicon_symptoms_dict['depressive neurosis'] = [2] #depression instead of dysthymia
lexicon_symptoms_dict['feel bad'] = [205] #feeling bad instead of 
lexicon_symptoms_dict['feel ill'] = [205] #feeling bad instead of fatigue
lexicon_symptoms_dict['breathing difficulties'] = [5] #shortness of breath instead of respiratory depression
lexicon_symptoms_dict['difficulty breathing'] = [5] #shortness of breath instead of respiratory depression
lexicon_symptoms_dict['respiratory difficulties'] = [5] #shortness of breath instead of respiratory depression
lexicon_symptoms_dict['vomiting blood'] = [64] #gastrointestinal hemorrhage instead of nausea and/or vomiting
lexicon_symptoms_dict['facial puffiness'] = [198] #facial edema instead of swelling
lexicon_symptoms_dict['bleeding breakthrough'] = [93] #vaginal bleeding instead of bleeding 
lexicon_symptoms_dict['bleeding diathesis'] = [156] #tendency to bleed instead of bleeding
lexicon_symptoms_dict['bleeding disorder'] = [156] #tendency to bleed instead of bleeding
lexicon_symptoms_dict['bleeding disorders'] = [156] #tendency to bleed instead of bleeding
lexicon_symptoms_dict['bleeding tendency'] = [156] #tendency to bleed instead of bleeding
lexicon_symptoms_dict['breakthrough bleeding'] = [93] #vaginal bleeding instead of bleeding
lexicon_symptoms_dict['intermenstrual bleeding'] = [93] #vaginal bleeding instead of bleeding
lexicon_symptoms_dict['spotting between menses'] = [93] #vaginal bleeding instead of bleeding
lexicon_symptoms_dict['wooziness'] = [18] #dizziness or vertigo instead of clouded consciousness
lexicon_symptoms_dict['paresis'] = [116] #muscle weakness instead of weakness
lexicon_symptoms_dict['peeling'] = [22] #skin lesion instead of skin irritation
lexicon_symptoms_dict['skin breakdown'] = [173] #impaired skin integrity instead of skin lesion
lexicon_symptoms_dict['spots'] = [22] #skin lesion instead of rash
lexicon_symptoms_dict['ulcerated'] = [81] #ulcer instead of skin lesion
lexicon_symptoms_dict['ulcerating'] = [81] #ulcer instead of skin lesion
lexicon_symptoms_dict['ulceration, nos'] = [81] #ulcer instead of skin lesion
lexicon_symptoms_dict['disturbances, sleep'] = [57] #sleep disorder instead of insomnia
lexicon_symptoms_dict['sleep disturbance'] = [57] #sleep disorder instead of insomnia
lexicon_symptoms_dict['sleep disturbances'] = [57] #sleep disorder instead of insomnia
lexicon_symptoms_dict['acquired lymphedema'] = [249] #lymphedema instead of peripheral edema
lexicon_symptoms_dict['acquired lymphoedema'] = [249] #lymphedema instead of peripheral edema
lexicon_symptoms_dict['urine output decreased'] = [301] #oliguria instead of lower urinary tract symptoms
lexicon_symptoms_dict['urine output low'] = [301] #oliguria instead of lower urinary tract symptoms
lexicon_symptoms_dict['urine production scanty'] = [301]  #oliguria instead of lower urinary tract symptoms
lexicon_symptoms_dict['urine volume deficient'] = [301] #oliguria instead of lower urinary tract symptoms
lexicon_symptoms_dict['volume urine decreased'] = [301] #oliguria instead of lower urinary tract symptoms
lexicon_symptoms_dict['excess fluid'] = [109] #fluid retention instead of edema
lexicon_symptoms_dict['blocked nose'] = [223] #nasal obstruction insetad of sinonasal congestion
lexicon_symptoms_dict['difficulties gait'] = [39] #abnormal gait instead of walking disability
lexicon_symptoms_dict['gait difficulty'] = [39] #abnormal gait instead of walking disability
lexicon_symptoms_dict['limited mobility'] = [179] #reduced mobility instead of abnormal gait
lexicon_symptoms_dict['pulmonary arrest'] = [40] #respiratory depression instead of sleep apnea
lexicon_symptoms_dict['loss of vision'] = [129] #blindness instead of visual changes
lexicon_symptoms_dict['vision loss'] = [129] #blindness instead of visual changes
lexicon_symptoms_dict['acute confusional state'] = [45] #confusion instead of mental status change
lexicon_symptoms_dict['bewilderment'] = [45] #confusion instead of clouded consciousness
lexicon_symptoms_dict['dazed'] = [45] #confusion instead of clouded consciousness
lexicon_symptoms_dict['dazed state'] = [45] #confusion instead of clouded consciousness
lexicon_symptoms_dict['muddled'] = [45] #confusion instead of clouded consciousness
lexicon_symptoms_dict['blackout'] = [107] #loss of consciousness instead of syncope
lexicon_symptoms_dict['pass out'] = [107]  #loss of consciousness instead of syncope
lexicon_symptoms_dict['passed out'] = [107]  #loss of consciousness instead of syncope
lexicon_symptoms_dict['passing out'] = [107]  #loss of consciousness instead of syncope
lexicon_symptoms_dict['black faeces'] = [181] #feces color: tarry instead of gastrointestinal hemorrhage
lexicon_symptoms_dict['black faeces symptom'] = [181] #feces color: tarry instead of gastrointestinal hemorrhage
lexicon_symptoms_dict['black feces'] = [181] #feces color: tarry instead of gastrointestinal hemorrhage
lexicon_symptoms_dict['black feces symptom'] = [181] #feces color: tarry instead of gastrointestinal hemorrhage
lexicon_symptoms_dict['black stool'] = [181] #feces color: tarry instead of gastrointestinal hemorrhage
lexicon_symptoms_dict['black stools'] = [181] #feces color: tarry instead of gastrointestinal hemorrhage
lexicon_symptoms_dict['blood in faeces'] = [99] #blood in stools instead of gastrointestinal hemorrhage
lexicon_symptoms_dict['blood in feces'] = [99] #blood in stools instead of gastrointestinal hemorrhage
lexicon_symptoms_dict['bloody stool'] = [99] #blood in stools instead of gastrointestinal hemorrhage
lexicon_symptoms_dict['dark stools'] = [181] #feces color: tarry instead of gastrointestinal hemorrhage
lexicon_symptoms_dict['faeces: blood'] = [99] #blood in stools instead of gastrointestinal hemorrhage
lexicon_symptoms_dict['feces: blood'] = [99] #blood in stools instead of gastrointestinal hemorrhage
lexicon_symptoms_dict['haematochezia'] = [64] #gastrointestinal hemorrhage instead of blood in stools
lexicon_symptoms_dict['melaena'] = [99] #blood in stools instead of gastrointestinal hemorrhage
lexicon_symptoms_dict['passage of bloody stools'] = [99] #blood in stools instead of gastrointestinal hemorrhage
lexicon_symptoms_dict['stool black'] = [181] #feces color: tarry instead of gastrointestinal hemorrhage
lexicon_symptoms_dict['stool tarry'] = [181] #feces color: tarry instead of gastrointestinal hemorrhage
lexicon_symptoms_dict['tarry stool'] = [181] #feces color: tarry instead of gastrointestinal hemorrhage
lexicon_symptoms_dict['tarry stools'] = [181] #feces color: tarry instead of gastrointestinal hemorrhage
lexicon_symptoms_dict['excessive overactivity'] = [158] #psychomotor agitation instead of agitation
lexicon_symptoms_dict['excessive overactivity, nos'] = [158] #psychomotor agitation instead of agitation
lexicon_symptoms_dict['increased purposeless goalless activity'] = [158] #psychomotor agitation instead of agitation
lexicon_symptoms_dict['increased purposeless goalless activity, nos'] = [158] #psychomotor agitation instead of agitation
lexicon_symptoms_dict['restless'] = [128] #restlessness instead of agitation
lexicon_symptoms_dict['restlessness marked'] = [128] #restlessness instead of agitation
lexicon_symptoms_dict['unable to keep still'] = [128] #restlessness instead of agitation
lexicon_symptoms_dict['hair thinning'] = [75] #hair loss instead of hypotrichosis
lexicon_symptoms_dict['affective psychosis nos'] = [145] #psychosis instead of mood swings
lexicon_symptoms_dict['muscle spasm'] = [88] #spasm instead of myotonia
lexicon_symptoms_dict['dysfunctional uterine bleeding'] = [139] #abnormal uterine bleeding instead of vaginal bleeding
lexicon_symptoms_dict['spotting'] = [127] #menstrual spotting instead of vaginal bleeding
lexicon_symptoms_dict['cold feel'] = [278] #feels cold instead of temperature intolerance
lexicon_symptoms_dict['cold feelings'] = [278] #feels cold instead of temperature intolerance
lexicon_symptoms_dict['feel cold'] = [278] #feels cold instead of temperature intolerance
lexicon_symptoms_dict['jerk'] = [243] #twitching instead of muscle twitching
lexicon_symptoms_dict['jerking'] = [243] #twitching instead of muscle twitching
lexicon_symptoms_dict['manic'] = [207] #manic mood instead of mania
lexicon_symptoms_dict['swollen throat'] = [280] #throat swelling instead of oropharyngeal swelling

# %%
lexicon_symptoms_dict_numbered = {k:v[0] for (k, v) in lexicon_symptoms_dict.items()}
lexicon_symptoms_dict_named = {k:basic_symptom_list[v] for (k, v) in lexicon_symptoms_dict_numbered.items()}

# %%
lexicon_symptoms_json_numbered = json.dumps(lexicon_symptoms_dict_numbered)
with open("lexicon_symptoms_dict_numbered.json","w") as f:
    f.write(lexicon_symptoms_json_numbered)

lexicon_symptoms_json_named = json.dumps(lexicon_symptoms_dict_named)
with open("lexicon_symptoms_dict_named.json","w") as f:
    f.write(lexicon_symptoms_json_named)

# %% [markdown]
# ### Level 2: From single symptom to the category of the symptom

# %%
# Reading the categorisation of the lexicon symptoms
symptom_categorisation = pd.read_csv('Symptoms Categorisation.csv')

# %%
symptom_categorisation
# Out:
#                                   Category  \
# 0                           Other Symptoms
# 1                                  General
# 2                       Body Pain/Mobility
# 3   Mental Health/Psychological/Behavioral
# 4                                    Sleep
# 5                      Otorhinolaryngology
# 6                     Neurological/Ocular
# 7                        Cardiorespiratory
# 8                         Gastrointestinal
# 9                       Vascular/Lymphatic
# 10                                 Urinary
# 11                               Cutaneous
# 12                          Women's Health
#
#                                              Symptoms
# 0   sexual dysfunction, priapism, dyspareunia, lib...
# 1   fatigue, fever, bleeding, weight loss, weaknes...
# 2   pain, joint pain, myalgia, back pain, pain in ...
# 3   stress, anxiety, depression, suffering, mental...
# 4   insomnia, sleep apnea, sleep disorder, somnole...
# 5   sinonasal congestion, nasal symptoms, pain in ...
# 6   headaches,  facial pain, dizziness or vertigo,...
# 7   shortness of breath, cough, chest pain, wheezi...
# 8   nausea and/or vomiting, gastroesophageal reflu...
# 9   bruising, lymphadenopathy, laryngeal edema, ly...
# 10  lower urinary tract symptoms ,urinary incontin...
# 11  skin lesion, rash, itching, erythema ,changes ...
# 12  vaginal bleeding, irregular periods, abnormal ...

# %%
# Transforming the symptoms in the Symptoms column from string type to list type
symptom_categorisation['Symptoms'] = symptom_categorisation['Symptoms'].apply(lambda x: x.replace("'", '').split(','))

# %%
symptom_categorisation
# Out:
#                                   Category  \
# 0                           Other Symptoms
# 1                                  General
# 2                       Body Pain/Mobility
# 3   Mental Health/Psychological/Behavioral
# 4                                    Sleep
# 5                      Otorhinolaryngology
# 6                     Neurological/Ocular
# 7                        Cardiorespiratory
# 8                         Gastrointestinal
# 9                       Vascular/Lymphatic
# 10                                 Urinary
# 11                               Cutaneous
# 12                          Women's Health
#
#                                              Symptoms
# 0   [sexual dysfunction,  priapism,  dyspareunia, ...
# 1   [fatigue,  fever,  bleeding,  weight loss,  we...
# 2   [pain,  joint pain,  myalgia,  back pain,  pai...
# 3   [stress,  anxiety,  depression,  suffering,  m...
# 4   [insomnia,  sleep apnea,  sleep disorder,  som...
# 5   [sinonasal congestion,  nasal symptoms,  pain ...
# 6   [headaches,   facial pain,  dizziness or verti...
# 7   [shortness of breath,  cough,  chest pain,  wh...
# 8   [nausea and/or vomiting,  gastroesophageal ref...
# 9   [bruising,  lymphadenopathy,  laryngeal edema,...
# 10  [lower urinary tract symptoms , urinary incont...
# 11  [skin lesion,  rash,  itching,  erythema , cha...
# 12  [vaginal bleeding,  irregular periods,  abnorm...

# %%
# Creating a dictionary where each symptom is associated with its category
symptom_category_dict = {}

for i in range(len(symptom_categorisation)):
    for symptom in symptom_categorisation['Symptoms'][i]:
        symptom = symptom.strip()
        if symptom != '':
            symptom_category_dict[symptom] = symptom_categorisation['Category'][i]

all_symptoms_list = list(symptom_category_dict.keys())
original_symptom_list = pd.read_csv('post_covid19_symptom_lexicon.csv')['symptom']
len(original_symptom_list.to_list())

# %%
# Saving the dictionary in json format
symptom_synonym_category_dict = {k:symptom_category_dict[v] for (k, v) in lexicon_symptoms_dict_named.items()}
symptom_synonym_category_dict_json = json.dumps(symptom_synonym_category_dict)
with open("symptom_synonym_category_dict_2.json","w") as f:
    f.write(symptom_synonym_category_dict_json)
